# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({ 
    'grades': [100, 99, 70, 80], 
    'students': ['matanel', 'enosh', 'alef', 'omer']
})
df
# Out:
#    grades students
# 0     100  matanel
# 1      99    enosh
# 2      70     alef
# 3      80     omer

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
data = pd.read_csv(url, sep = '\t')
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data.shape
# Out:
# (4622, 5)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
data.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=4622, step=1),
#  Index(['order_id', 'quantity', 'item_name', 'choice_description',
#         'item_price'],
#        dtype='object')]

# %%
data.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
data.describe(include='all').round(2)
# Out:
#         order_id  quantity     item_name choice_description item_price
# count    4622.00   4622.00          4622               3376       4622
# unique       NaN       NaN            50               1043         78
# top          NaN       NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq         NaN       NaN           726                134        730
# mean      927.25      1.08           NaN                NaN        NaN
# std       528.89      0.41           NaN                NaN        NaN
# min         1.00      1.00           NaN                NaN        NaN
# 25%       477.25      1.00           NaN                NaN        NaN
# 50%       926.00      1.00           NaN                NaN        NaN
# 75%      1393.00      1.00           NaN                NaN        NaN
# max      1834.00     15.00           NaN                NaN        NaN

# %%
data.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
data.tail(2)
# Out:
#       order_id  quantity           item_name  \
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
data.sample(5)
# Out:
#       order_id  quantity            item_name  \
# 4379      1747         1      Chicken Burrito
# 1210       494         1         Chicken Bowl
# 894        369         1  Chips and Guacamole
# 1738       701         1   Chicken Salad Bowl
# 851        351         1        Carnitas Bowl
#
#                                      choice_description item_price
# 4379  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...    $11.25
# 1210  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...    $10.98
# 894                                                 NaN     $3.99
# 1738  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.25
# 851   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25

# %%
data.sample(5).describe()
# Out:
#           order_id  quantity
# count     5.000000       5.0
# mean    892.600000       1.0
# std     773.518455       0.0
# min     194.000000       1.0
# 25%     317.000000       1.0
# 50%     490.000000       1.0
# 75%    1676.000000       1.0
# max    1786.000000       1.0

# %%
data['item_name'] # series
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
data.item_name # series
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
data['item_name'][0:3]
# Out:
# 0    Chips and Fresh Tomato Salsa
# 1                            Izze
# 2                Nantucket Nectar
# Name: item_name, dtype: object

# %%
res = data['item_name'][0:10]
res[res.str.contains('f')]
# Out:
# 6       Side of Chips
# 8    Steak Soft Tacos
# Name: item_name, dtype: object

# %%
data['quantity'].count()
# Out:
# 4622

# %%
data['quantity'].unique()
# Out:
# array([ 1,  2,  3,  4,  5, 15,  7,  8, 10])

# %%
data['quantity'].max()
# Out:
# 15

# %%
data['quantity'].nunique()
# Out:
# 9

# %%
data['item_name'].iloc[0:8].str.upper()
# Out:
# 0             CHIPS AND FRESH TOMATO SALSA
# 1                                     IZZE
# 2                         NANTUCKET NECTAR
# 3    CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                             CHICKEN BOWL
# 5                             CHICKEN BOWL
# 6                            SIDE OF CHIPS
# 7                            STEAK BURRITO
# Name: item_name, dtype: object

# %%
data[['item_name', 'quantity']] # dataframe
# Out:
#                                   item_name  quantity
# 0              Chips and Fresh Tomato Salsa         1
# 1                                      Izze         1
# 2                          Nantucket Nectar         1
# 3     Chips and Tomatillo-Green Chili Salsa         1
# 4                              Chicken Bowl         2
# ...                                     ...       ...
# 4617                          Steak Burrito         1
# 4618                          Steak Burrito         1
# 4619                     Chicken Salad Bowl         1
# 4620                     Chicken Salad Bowl         1
# 4621                     Chicken Salad Bowl         1
#
# [4622 rows x 2 columns]

# %%
data.iloc[0, 0]
# Out:
# 1

# %%
data.iloc[0:10, 3]
# Out:
# 0                                                  NaN
# 1                                         [Clementine]
# 2                                              [Apple]
# 3                                                  NaN
# 4    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 6                                                  NaN
# 7    [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 8    [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...
# 9    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# Name: choice_description, dtype: object

# %%
data.iloc[0:20:2, 1:3]
# Out:
#     quantity                     item_name
# 0          1  Chips and Fresh Tomato Salsa
# 2          1              Nantucket Nectar
# 4          2                  Chicken Bowl
# 6          1                 Side of Chips
# 8          1              Steak Soft Tacos
# 10         1           Chips and Guacamole
# 12         1            Chicken Soft Tacos
# 14         1           Chips and Guacamole
# 16         1               Chicken Burrito
# 18         2                   Canned Soda

# %%
data.loc[:, 'item_name']
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
data.loc[10:30:5, 'item_price']
# Out:
# 10    $4.45
# 15    $2.39
# 20    $4.45
# 25    $2.39
# 30    $2.39
# Name: item_price, dtype: object

# %%
data.loc[10:40:7, ['item_name', 'item_price']]
# Out:
#                                 item_name item_price
# 10                    Chips and Guacamole     $4.45
# 17                        Chicken Burrito     $8.49
# 24                                   Izze     $3.39
# 31                          Steak Burrito     $8.99
# 38  Chips and Tomatillo Green Chili Salsa     $2.95

# %%
data.loc[10:40:7, ['item_name', 'item_price']]['item_name']
# Out:
# 10                      Chips and Guacamole
# 17                          Chicken Burrito
# 24                                     Izze
# 31                            Steak Burrito
# 38    Chips and Tomatillo Green Chili Salsa
# Name: item_name, dtype: object

# %%
data.loc[10:40:7, ['item_name', 'item_price']]['item_name'].iloc[0:3]
# Out:
# 10    Chips and Guacamole
# 17        Chicken Burrito
# 24                   Izze
# Name: item_name, dtype: object

# %%
data.loc[10:40:7, 'item_name':'item_price']
# Out:
#                                 item_name  \
# 10                    Chips and Guacamole
# 17                        Chicken Burrito
# 24                                   Izze
# 31                          Steak Burrito
# 38  Chips and Tomatillo Green Chili Salsa
#
#                                    choice_description item_price
# 10                                                NaN     $4.45
# 17  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...     $8.49
# 24                                       [Grapefruit]     $3.39
# 31  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...     $8.99
# 38                                                NaN     $2.95

# %%
data.head(1)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
#
#   item_price
# 0     $2.39

# %%
data.drop(0, axis=0).head(1)
# Out:
#    order_id  quantity item_name choice_description item_price
# 1         1         1      Izze       [Clementine]     $3.39

# %%
data.drop([0, 1], axis=0).head(1)
# Out:
#    order_id  quantity         item_name choice_description item_price
# 2         1         1  Nantucket Nectar            [Apple]     $3.39

# %%
data.drop('item_name', axis=1).head(1)
# Out:
#    order_id  quantity choice_description item_price
# 0         1         1                NaN     $2.39

# %%
data.drop(['item_name', 'quantity'], axis=1).head(1)
# Out:
#    order_id choice_description item_price
# 0         1                NaN     $2.39

# %%
data.nunique()
# Out:
# order_id              1834
# quantity                 9
# item_name               50
# choice_description    1043
# item_price              78
# dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4617    False
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# Length: 4622, dtype: bool

# %%
data.duplicated(subset="quantity")
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 4617     True
# 4618     True
# 4619     True
# 4620     True
# 4621     True
# Length: 4622, dtype: bool

# %%
data.drop_duplicates(subset="quantity", keep="last", ignore_index=True)
# Out:
#    order_id  quantity                     item_name  \
# 0       970         5                 Bottled Water
# 1      1443        15  Chips and Fresh Tomato Salsa
# 2      1443         7                 Bottled Water
# 3      1559         8                 Side of Chips
# 4      1660        10                 Bottled Water
# 5      1671         3                 Bottled Water
# 6      1786         4             Canned Soft Drink
# 7      1822         2                 Bottled Water
# 8      1834         1            Chicken Salad Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $7.50
# 1                                                NaN    $44.25
# 2                                                NaN    $10.50
# 3                                                NaN    $13.52
# 4                                                NaN    $15.00
# ...

# %%
(data.drop_duplicates(subset="quantity", keep="last", ignore_index=True)
    .duplicated(subset='quantity')
)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
data.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
data.fillna(0)
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                     0     $2.39
# ...

# %%
data.fillna({ 'choice_description': 100 })
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   100     $2.39
# ...

# %%
data.dropna()
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# ...

# %%
data.dropna(subset='choice_description')
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# ...

# %%
data.loc[data['item_name'].str.contains('e')]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data.loc[data['item_name'].str.contains('e')]['item_name'][0:3]
# Out:
# 0    Chips and Fresh Tomato Salsa
# 1                            Izze
# 2                Nantucket Nectar
# Name: item_name, dtype: object

# %%
data.loc[data['item_name'].str.startswith('C')].head(2)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description item_price
# 0                NaN     $2.39
# 3                NaN     $2.39

# %%
data.loc[data['quantity'] > 1, ['item_name', 'item_price']]
# Out:
#                item_name item_price
# 4           Chicken Bowl    $16.98
# 18           Canned Soda     $2.18
# 51           Canned Soda     $2.18
# 135   Chicken Salad Bowl    $22.50
# 148        Steak Burrito    $17.98
# ...                  ...        ...
# 4491   Canned Soft Drink     $5.00
# 4499   Canned Soft Drink     $2.50
# 4560   Canned Soft Drink     $2.50
# 4561  Chicken Salad Bowl    $17.50
# 4582       Bottled Water     $3.00
#
# [267 rows x 2 columns]

# %%
data.loc[data['item_name'].isin(['Canned Soft Drink', 'Bottled Water'])]
# Out:
#       order_id  quantity          item_name choice_description item_price
# 34          17         1      Bottled Water                NaN     $1.09
# 87          38         1      Bottled Water                NaN     $1.09
# 263        114         1  Canned Soft Drink             [Coke]     $1.25
# 292        127         1  Canned Soft Drink           [Sprite]     $1.25
# 318        138         1      Bottled Water                NaN     $1.09
# ...        ...       ...                ...                ...        ...
# 4598      1826         1      Bottled Water                NaN     $1.50
# 4601      1827         1  Canned Soft Drink        [Diet Coke]     $1.25
# 4606      1828         1  Canned Soft Drink             [Coke]     $1.25
# 4609      1829         1  Canned Soft Drink           [Sprite]     $1.25
# 4614      1831         1      Bottled Water                NaN     $1.50
#
# [463 rows x 5 columns]

# %%
data.query("item_name == 'Bottled Water'").head(2)
# Out:
#     order_id  quantity      item_name choice_description item_price
# 34        17         1  Bottled Water                NaN     $1.09
# 87        38         1  Bottled Water                NaN     $1.09

# %%
data.query("quantity in [1, 2, 3]").head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
data.query("quantity > 2 and item_name == 'Chicken Bowl'")
# Out:
#       order_id  quantity     item_name  \
# 409        178         3  Chicken Bowl
# 1514       616         3  Chicken Bowl
#
#                                      choice_description item_price
# 409   [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 1514  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $26.25

# %%
data.query(
    "quantity > 2 or item_name == 'Bottled Water'"
)
# Out:
#       order_id  quantity      item_name choice_description item_price
# 34          17         1  Bottled Water                NaN     $1.09
# 87          38         1  Bottled Water                NaN     $1.09
# 318        138         1  Bottled Water                NaN     $1.09
# 329        143         1  Bottled Water                NaN     $1.50
# 376        163         1  Bottled Water                NaN     $1.50
# ...        ...       ...            ...                ...        ...
# 4568      1817         1  Bottled Water                NaN     $1.50
# 4570      1817         1  Bottled Water                NaN     $1.50
# 4582      1822         2  Bottled Water                NaN     $3.00
# 4598      1826         1  Bottled Water                NaN     $1.50
# 4614      1831         1  Bottled Water                NaN     $1.50
#
# [194 rows x 5 columns]

# %%
data.sort_values('item_name')
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description item_price
# 3389                                        [Diet Coke]    $12.98
# 341                                         [Diet Coke]     $6.49
# 1849                                             [Coke]     $6.49
# 1860                                        [Diet Coke]     $6.49
# 2713                                             [Coke]     $6.49
# ...

# %%
data.sort_index(ascending=False)
# Out:
#       order_id  quantity                              item_name  \
# 4621      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4619      1834         1                     Chicken Salad Bowl
# 4618      1833         1                          Steak Burrito
# 4617      1833         1                          Steak Burrito
# ...        ...       ...                                    ...
# 4            2         2                           Chicken Bowl
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 2            1         1                       Nantucket Nectar
# 1            1         1                                   Izze
# 0            1         1           Chips and Fresh Tomato Salsa
#
#                                      choice_description item_price
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
# ...

# %%
data.columns = [col.upper() for col in data.columns]
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data.rename(columns={'item_name': 'itemname'})
# Out:
#       order_id  quantity                               itemname  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data.rename(columns=lambda x: x.upper())
# Out:
#       ORDER_ID  QUANTITY                              ITEM_NAME  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      CHOICE_DESCRIPTION ITEM_PRICE
# 0                                                   NaN     $2.39
# ...

# %%
data['item_quantity'] = data['quantity'].astype(str) + data['item_name'] 
data.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price                  item_quantity
# 0     $2.39   1Chips and Fresh Tomato Salsa
# 1     $3.39                           1Izze

# %%
vegan_map = { 'Bottled Water': 'Vegan', 'Chicken Salad Bowl': 'None Vegan',
             'Chips and Tomatillo-Green Chili Salsa': 'Vegan', 
             'Steak Burrito': 'None Vegan', 'Nantucket Nectar': 'Vegan',
            'Chips and Fresh Tomato Salsa': 'Vegan'}

data['is_vegan'] = data['item_name'].map(vegan_map)
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                   NaN     $2.39
# ...

# %%
data.groupby('item_name').sum().head(3)
# Out:
#                    order_id  quantity  \
# item_name
# 6 Pack Soft Drink     52322        55
# Barbacoa Bowl         53972        66
# Barbacoa Burrito      74718        91
#
#                                                   choice_description  \
# item_name
# 6 Pack Soft Drink  [Sprite][Diet Coke][Coke][Diet Coke][Diet Coke...
# Barbacoa Bowl      [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# Barbacoa Burrito   [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...
#
#                                                           item_price  \
# item_name
# 6 Pack Soft Drink  $6.49 $6.49 $6.49 $6.49 $6.49 $6.49 $6.49 $6.4...
# Barbacoa Bowl      $11.75 $11.75 $9.25 $8.99 $9.25 $11.75 $9.25 $...
# Barbacoa Burrito   $8.99 $9.25 $9.25 $11.75 $11.75 $9.25 $8.99 $1...
#
#                                                        item_quantity is_vegan
# item_name
# 6 Pack Soft Drink  16 Pack Soft Drink16 Pack Soft Drink16 Pack So...        0
# ...

# %%
data.groupby('item_name')['quantity'].sum().head(3)
# Out:
# item_name
# 6 Pack Soft Drink    55
# Barbacoa Bowl        66
# Barbacoa Burrito     91
# Name: quantity, dtype: int64

# %%
data.groupby(['item_name', 'quantity']).sum().head(3)
# Out:
#                             order_id  \
# item_name         quantity
# 6 Pack Soft Drink 1            50962
#                   2             1360
# Barbacoa Bowl     1            53972
#
#                                                            choice_description  \
# item_name         quantity
# 6 Pack Soft Drink 1         [Sprite][Diet Coke][Coke][Diet Coke][Diet Coke...
#                   2                                               [Diet Coke]
# Barbacoa Bowl     1         [Roasted Chili Corn Salsa, [Fajita Vegetables,...
#
#                                                                    item_price  \
# item_name         quantity
# 6 Pack Soft Drink 1         $6.49 $6.49 $6.49 $6.49 $6.49 $6.49 $6.49 $6.4...
#                   2                                                   $12.98
# Barbacoa Bowl     1         $11.75 $11.75 $9.25 $8.99 $9.25 $11.75 $9.25 $...
#
#                                                                 item_quantity  \
# ...

# %%
data.groupby('item_name')['quantity'].agg('sum').head(3)
# Out:
# item_name
# 6 Pack Soft Drink    55
# Barbacoa Bowl        66
# Barbacoa Burrito     91
# Name: quantity, dtype: int64

# %%
data.groupby('item_name')['quantity'].agg(['sum', 'min']).head(3)
# Out:
#                    sum  min
# item_name
# 6 Pack Soft Drink   55    1
# Barbacoa Bowl       66    1
# Barbacoa Burrito    91    1
